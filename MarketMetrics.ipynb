# %% [markdown]
# # MarketMetrics: A Finance and e-Commerce Deep Dive

# %% [markdown]
# ## Olist eCommerce Dataset

# %% [markdown]
# ### Loading the datasets

# %% [markdown]
# #### Importing pandas to work with my datasets since they're tabular data

# %%
import pandas as pd

# %%
# Loading the first dataset

customers_df = pd.read_csv("olist_customers_dataset.csv")
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
orders_df = pd.read_csv("olist_orders_dataset.csv")
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_items_df = pd.read_csv("olist_order_items_dataset.csv")
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_items_df.head(10)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
payments_df = pd.read_csv("olist_order_payments_dataset.csv")
payments_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
payments_df.head(10)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5  298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6  771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7  3d7239c394a212faae122962df514ac7                   1  credit_card
# 8  1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9  0573b5e23cbd798006520e1d5b4c6714                   1       boleto
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# ...

# %%
payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
reviews_df = pd.read_csv("olist_order_reviews_dataset.csv")
reviews_df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
reviews_df.head(10)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5  15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6  07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7  7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
# 8  a3f6f7f6f433de0aefbb97da197c554c  9c214ac970e84273583ab523dfafd09b
# 9  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# ...

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
products_df = pd.read_csv("olist_products_dataset.csv")
products_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
products_df.head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# ...

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Merging key datasets

# %%
orders_customers_df = orders_df.merge(customers_df, on='customer_id', how='left')
orders_customers_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_customers_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %%
orders_customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
#  8   customer_unique_id             99441 non-null  object
#  9   customer_zip_code_prefix       99441 non-null  int64
#  10  customer_city                  99441 non-null  object
#  11  customer_state                 99441 non-null  object
# dtypes: int64(1), object(11)
# ...

# %%
orders_full_df = orders_customers_df.merge(order_items_df, on='order_id', how='left')
orders_full_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 113420  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113421  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113422  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113423  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113424  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_full_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %%
orders_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113425 entries, 0 to 113424
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113425 non-null  object
#  1   customer_id                    113425 non-null  object
#  2   order_status                   113425 non-null  object
#  3   order_purchase_timestamp       113425 non-null  object
#  4   order_approved_at              113264 non-null  object
#  5   order_delivered_carrier_date   111457 non-null  object
#  6   order_delivered_customer_date  110196 non-null  object
#  7   order_estimated_delivery_date  113425 non-null  object
#  8   customer_unique_id             113425 non-null  object
#  9   customer_zip_code_prefix       113425 non-null  int64
#  10  customer_city                  113425 non-null  object
#  11  customer_state                 113425 non-null  object
# ...

# %%
orders_payments_df = orders_full_df.merge(payments_df, on='order_id', how='left')
orders_payments_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118429  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118430  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118431  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118432  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118433  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_payments_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 5  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 6  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 7  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 8  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 9  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# ...

# %%
orders_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118434 entries, 0 to 118433
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118434 non-null  object
#  1   customer_id                    118434 non-null  object
#  2   order_status                   118434 non-null  object
#  3   order_purchase_timestamp       118434 non-null  object
#  4   order_approved_at              118258 non-null  object
#  5   order_delivered_carrier_date   116360 non-null  object
#  6   order_delivered_customer_date  115037 non-null  object
#  7   order_estimated_delivery_date  118434 non-null  object
#  8   customer_unique_id             118434 non-null  object
#  9   customer_zip_code_prefix       118434 non-null  int64
#  10  customer_city                  118434 non-null  object
#  11  customer_state                 118434 non-null  object
# ...

# %%
orders_reviews_df = orders_payments_df.merge(reviews_df, on='order_id', how='left')
orders_reviews_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 119138  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 119139  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 119140  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119141  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119142  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_reviews_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 5  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 6  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 7  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 8  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 9  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# ...

# %%
orders_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  object
#  1   customer_id                    119143 non-null  object
#  2   order_status                   119143 non-null  object
#  3   order_purchase_timestamp       119143 non-null  object
#  4   order_approved_at              118966 non-null  object
#  5   order_delivered_carrier_date   117057 non-null  object
#  6   order_delivered_customer_date  115722 non-null  object
#  7   order_estimated_delivery_date  119143 non-null  object
#  8   customer_unique_id             119143 non-null  object
#  9   customer_zip_code_prefix       119143 non-null  int64
#  10  customer_city                  119143 non-null  object
#  11  customer_state                 119143 non-null  object
# ...

# %%
# Checking for duplicates

orders_reviews_df.duplicated(subset='review_id').sum()
# Out:
# 20732

# %%
# Dropping rows with duplicate reviews

unique_reviews_df = orders_reviews_df.drop_duplicates(subset='review_id')
unique_reviews_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 5       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 6       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 119137  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 119138  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 119139  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 119140  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119142  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
unique_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98411 entries, 0 to 119142
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       98411 non-null  object
#  1   customer_id                    98411 non-null  object
#  2   order_status                   98411 non-null  object
#  3   order_purchase_timestamp       98411 non-null  object
#  4   order_approved_at              98281 non-null  object
#  5   order_delivered_carrier_date   96698 non-null  object
#  6   order_delivered_customer_date  95602 non-null  object
#  7   order_estimated_delivery_date  98411 non-null  object
#  8   customer_unique_id             98411 non-null  object
#  9   customer_zip_code_prefix       98411 non-null  int64
#  10  customer_city                  98411 non-null  object
#  11  customer_state                 98411 non-null  object
# ...

# %%
final_df = unique_reviews_df.merge(products_df, on='product_id', how='left')
final_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 98406  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 98407  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 98408  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 98409  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 98410  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
final_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98411 entries, 0 to 98410
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       98411 non-null  object
#  1   customer_id                    98411 non-null  object
#  2   order_status                   98411 non-null  object
#  3   order_purchase_timestamp       98411 non-null  object
#  4   order_approved_at              98281 non-null  object
#  5   order_delivered_carrier_date   96698 non-null  object
#  6   order_delivered_customer_date  95602 non-null  object
#  7   order_estimated_delivery_date  98411 non-null  object
#  8   customer_unique_id             98411 non-null  object
#  9   customer_zip_code_prefix       98411 non-null  int64
#  10  customer_city                  98411 non-null  object
#  11  customer_state                 98411 non-null  object
# ...

# %% [markdown]
# ### Handling missing values & data cleaning

# %% [markdown]
# #### Visualizing missing values

# %%
# Loading the merged DataFrame from previous work (assuming it's already in memory as final_df)
# Generating a summary of missing values by column
missing_values_summary = final_df.isnull().sum().to_frame(name='Missing Values')
missing_values_summary['% Missing'] = (missing_values_summary['Missing Values'] / len(final_df)) * 100

missing_values_summary
# Out:
#                                Missing Values  % Missing
# order_id                                    0   0.000000
# customer_id                                 0   0.000000
# order_status                                0   0.000000
# order_purchase_timestamp                    0   0.000000
# order_approved_at                         130   0.132099
# order_delivered_carrier_date             1713   1.740659
# order_delivered_customer_date            2809   2.854356
# order_estimated_delivery_date               0   0.000000
# customer_unique_id                          0   0.000000
# customer_zip_code_prefix                    0   0.000000
# customer_city                               0   0.000000
# customer_state                              0   0.000000
# order_item_id                             726   0.737722
# product_id                                726   0.737722
# seller_id                                 726   0.737722
# ...

# %%
final_df.to_csv('final_olist_dataset.csv', index=False)

# %%
# !pip install missingno

# %%
import missingno as msno
import matplotlib.pyplot as plt

# Visualizing missing data as a matrix
msno.matrix(final_df)
plt.show()

# Bar plot of missing values per column
msno.bar(final_df)
plt.show()

# %% [markdown]
# #### Cleaning missing values

# %%
# Replacing missing review titles and messages with placeholders: "No title" and "No comment"

final_df['review_comment_title'] = final_df['review_comment_title'].fillna('No Title')
final_df['review_comment_message'] = final_df['review_comment_message'].fillna('No Comment')
final_df['review_comment_title'].head(10)
final_df['review_comment_message'].head(10)
# Out:
# 0    Não testei o produto ainda, mas ele veio corre...
# 1                                 Muito bom o produto.
# 2                                           No Comment
# 3    O produto foi exatamente o que eu esperava e e...
# 4                                           No Comment
# 5                                           No Comment
# 6                 fiquei triste por n ter me atendido.
# 7                                           No Comment
# 8                                           No Comment
# 9                                           No Comment
# Name: review_comment_message, dtype: object

# %%
final_df[['review_comment_title', 'review_comment_message']].head(10)
# Out:
#   review_comment_title                             review_comment_message
# 0             No Title  Não testei o produto ainda, mas ele veio corre...
# 1     Muito boa a loja                               Muito bom o produto.
# 2             No Title                                         No Comment
# 3             No Title  O produto foi exatamente o que eu esperava e e...
# 4             No Title                                         No Comment
# 5             No Title                                         No Comment
# 6             No Title               fiquei triste por n ter me atendido.
# 7             No Title                                         No Comment
# 8             No Title                                         No Comment
# 9             No Title                                         No Comment

# %%
# Converting timestamp and date columns to datetime
timestamp_cols = [
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date',
    'shipping_limit_date',
    'review_answer_timestamp',
    'review_creation_date'
]

for col in timestamp_cols:
    final_df[col] = pd.to_datetime(final_df[col], errors='coerce')

final_df[col]
# Out:
# 0       2017-10-11
# 1       2018-08-08
# 2       2018-08-18
# 3       2017-12-03
# 4       2018-02-17
#            ...
# 98406   2017-03-22
# 98407   2018-03-01
# 98408   2017-09-22
# 98409   2018-01-26
# 98410   2018-03-17
# Name: review_creation_date, Length: 98411, dtype: datetime64[ns]

# %%
final_df[col].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 98411 entries, 0 to 98410
# Series name: review_creation_date
# Non-Null Count  Dtype
# --------------  -----
# 98410 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 769.0 KB

# %%
final_df[timestamp_cols + ['review_creation_date']].dtypes
# Out:
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# shipping_limit_date              datetime64[ns]
# review_answer_timestamp          datetime64[ns]
# review_creation_date             datetime64[ns]
# review_creation_date             datetime64[ns]
# dtype: object

# %%
# Dropping 726 rows where any of these key item-related columns are missing (having null values)

final_df_cleaned = final_df.dropna(
    subset=[
        'order_item_id', 'product_id', 'seller_id',
        'price', 'freight_value', 'shipping_limit_date'
    ]
)

# Checking shape change (expecting difference of 726 rows)
print(f"Original shape is", final_df.shape)
print(f"New shape after dropping: {final_df_cleaned.shape}")
# Out:
# Original shape is (98411, 36)
# New shape after dropping: (97685, 36)

# %%
# Checking remaining null values

cleaned_missing_values_summary = final_df_cleaned.isnull().sum().to_frame(name='Missing Values')
cleaned_missing_values_summary['% Missing'] = (cleaned_missing_values_summary['Missing Values'] / len(final_df_cleaned)) * 100
cleaned_missing_values_summary = cleaned_missing_values_summary[cleaned_missing_values_summary['Missing Values'] > 0]

cleaned_missing_values_summary
# Out:
#                                Missing Values  % Missing
# order_approved_at                          14   0.014332
# order_delivered_carrier_date              988   1.011414
# order_delivered_customer_date            2083   2.132364
# payment_sequential                          1   0.001024
# payment_type                                1   0.001024
# payment_installments                        1   0.001024
# payment_value                               1   0.001024
# review_id                                   1   0.001024
# review_score                                1   0.001024
# review_creation_date                        1   0.001024
# review_answer_timestamp                     1   0.001024
# product_category_name                    1401   1.434202
# product_name_lenght                      1401   1.434202
# product_description_lenght               1401   1.434202
# product_photos_qty                       1401   1.434202
# ...

# %%
# Dropping rows where any of the single-row missing columns are null
single_row_missing_cols = [
    'payment_sequential', 'payment_type', 'payment_installments', 'payment_value',
    'review_id', 'review_score', 'review_creation_date', 'review_answer_timestamp'
]

final_df_cleaned = final_df_cleaned.dropna(subset=single_row_missing_cols)

# Confirming new shape
print("New shape after dropping single-row issues:", final_df_cleaned.shape)
# Out:
# New shape after dropping single-row issues: (97683, 36)

# %%
# Checking remaining null values

cleaned_missing_values_summary = final_df_cleaned.isnull().sum().to_frame(name='Missing Values')
cleaned_missing_values_summary['% Missing'] = (cleaned_missing_values_summary['Missing Values'] / len(final_df_cleaned)) * 100
cleaned_missing_values_summary = cleaned_missing_values_summary[cleaned_missing_values_summary['Missing Values'] > 0]

cleaned_missing_values_summary
# Out:
#                                Missing Values  % Missing
# order_approved_at                          14   0.014332
# order_delivered_carrier_date              988   1.011435
# order_delivered_customer_date            2083   2.132408
# product_category_name                    1401   1.434231
# product_name_lenght                      1401   1.434231
# product_description_lenght               1401   1.434231
# product_photos_qty                       1401   1.434231
# product_weight_g                           16   0.016380
# product_length_cm                          16   0.016380
# product_height_cm                          16   0.016380
# product_width_cm                           16   0.016380

# %%
# Date/Time data cleaning

# For 'order_approved_at' (filling null values with median delay times)
delay = final_df_cleaned['order_approved_at'] - final_df_cleaned['order_purchase_timestamp']
print("Mean Delay:", delay.mean())
print("Median Delay:", delay.median())
# Using the median delay
median_delay = (
    final_df_cleaned['order_approved_at'] - final_df_cleaned['order_purchase_timestamp']
).median()

# Filling missing values using the median delay
final_df_cleaned['order_approved_at'] = final_df_cleaned['order_approved_at'].fillna(
    final_df_cleaned['order_purchase_timestamp'] + median_delay
)

final_df_cleaned['order_approved_at'].head(10)
# Out:
# Mean Delay: 0 days 10:19:34.060408113
# Median Delay: 0 days 00:20:36
# 0   2017-10-02 11:07:15
# 1   2018-07-26 03:24:27
# 2   2018-08-08 08:55:23
# 3   2017-11-18 19:45:59
# 4   2018-02-13 22:20:29
# 5   2017-07-09 22:10:13
# 6   2017-04-13 13:25:17
# 7   2017-05-16 13:22:11
# 8   2017-01-25 02:50:47
# 9   2017-07-29 12:05:32
# Name: order_approved_at, dtype: datetime64[ns]

# %%
# Date/Time 
#For 'order_delivered_carrier_date'
# Calculating the time difference between carrier pickup and approval
carrier_delay = final_df_cleaned['order_delivered_carrier_date'] - final_df_cleaned['order_approved_at']

# Computing median delay
median_carrier_delay = carrier_delay.median()
print("Median Carrier Delay:", median_carrier_delay)

# Filling missing values using this delay
final_df_cleaned['order_delivered_carrier_date'].fillna(
    final_df_cleaned['order_approved_at'] + median_carrier_delay,
    inplace=True
)
# Out:
# Median Carrier Delay: 1 days 19:34:37

# %%
# Date/Time data cleaning

# Calculating delay between carrier pickup and customer delivery
delivery_delay = final_df_cleaned['order_delivered_customer_date'] - final_df_cleaned['order_delivered_carrier_date']

# Median delay
median_delivery_delay = delivery_delay.median()
print("Median Delivery Delay:", median_delivery_delay)

# Filling missing values
final_df_cleaned['order_delivered_customer_date'].fillna(
    final_df_cleaned['order_delivered_carrier_date'] + median_delivery_delay,
    inplace=True
)
# Out:
# Median Delivery Delay: 7 days 02:16:30.500000

# %%
# Checking approval time fill
check_filled_approved = final_df_cleaned[
    final_df_cleaned['order_approved_at'] == final_df_cleaned['order_purchase_timestamp']
][['order_purchase_timestamp', 'order_approved_at']]
check_filled_approved
# Out:
#       order_purchase_timestamp   order_approved_at
# 58         2017-03-13 18:14:36 2017-03-13 18:14:36
# 181        2017-03-14 16:25:43 2017-03-14 16:25:43
# 199        2017-03-09 22:17:49 2017-03-09 22:17:49
# 378        2017-03-22 17:25:28 2017-03-22 17:25:28
# 485        2017-03-13 11:36:11 2017-03-13 11:36:11
# ...                        ...                 ...
# 97918      2017-03-16 14:43:07 2017-03-16 14:43:07
# 98077      2017-03-12 12:10:44 2017-03-12 12:10:44
# 98220      2017-03-21 22:07:40 2017-03-21 22:07:40
# 98235      2017-03-21 10:42:25 2017-03-21 10:42:25
# 98406      2017-03-09 09:54:05 2017-03-09 09:54:05
#
# [1268 rows x 2 columns]

# %%
# Checking carrier delay fill
carrier_delay = final_df_cleaned['order_delivered_carrier_date'] - final_df_cleaned['order_approved_at']
check_filled_carrier = final_df_cleaned[carrier_delay == pd.Timedelta("1 days 19:34:37")]
check_filled_carrier
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 322    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# 393    1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# ...                                 ...                               ...
# 98009  c526fe83c01c48066394ff5d81f9ab9a  6c678c38f3a0874b7bfeeb2d5fb22876
# 98043  46bdec7cc92d926500bee756ee1df6dc  0cfcefc0ed0af6a2e601540feeac24e7
# 98115  aea0db338150b526dde24f6fd953a5ed  379a02efdc6a56bd27f99b95fc2f6c06
# 98118  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 98284  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
# Checking delivery delay fill
delivery_delay = final_df_cleaned['order_delivered_customer_date'] - final_df_cleaned['order_delivered_carrier_date']
check_filled_delivery = final_df_cleaned[delivery_delay == pd.Timedelta("7 days 02:16:30.5")]
check_filled_delivery
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 161    36530871a5e80138db53bcfd8a104d90  4dafe3c841d2d6cc8a8b6d25b35704b9
# ...                                 ...                               ...
# 98089  274a7f7e4f1c17b7434a830e9b8759b1  670af30ca5b8c20878fecdafa5ee01b9
# 98115  aea0db338150b526dde24f6fd953a5ed  379a02efdc6a56bd27f99b95fc2f6c06
# 98118  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 98156  636cdd02667dc8d76d9296bf20a6890a  c162256b133c76f79181ce61d66545db
# 98284  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
# Checking remaining null values

cleaned_missing_values_summary = final_df_cleaned.isnull().sum().to_frame(name='Missing Values')
cleaned_missing_values_summary['% Missing'] = (cleaned_missing_values_summary['Missing Values'] / len(final_df_cleaned)) * 100
cleaned_missing_values_summary = cleaned_missing_values_summary[cleaned_missing_values_summary['Missing Values'] > 0]

cleaned_missing_values_summary
# Out:
#                             Missing Values  % Missing
# product_category_name                 1401   1.434231
# product_name_lenght                   1401   1.434231
# product_description_lenght            1401   1.434231
# product_photos_qty                    1401   1.434231
# product_weight_g                        16   0.016380
# product_length_cm                       16   0.016380
# product_height_cm                       16   0.016380
# product_width_cm                        16   0.016380

# %%
# Dropping rows where ALL four metadata fields are missing
metadata_cols = [
    'product_category_name',
    'product_name_lenght',
    'product_description_lenght',
    'product_photos_qty'
]
mask_all_missing = final_df_cleaned[metadata_cols].isnull().all(axis=1)
final_df_cleaned = final_df_cleaned[~mask_all_missing]

# Imputing remaining missing values for fields not dropped
final_df_cleaned['product_category_name'].fillna('Unknown', inplace=True)
final_df_cleaned['product_name_lenght'].fillna(final_df_cleaned['product_name_lenght'].median(), inplace=True)
final_df_cleaned['product_description_lenght'].fillna(final_df_cleaned['product_description_lenght'].median(), inplace=True)
final_df_cleaned['product_photos_qty'].fillna(final_df_cleaned['product_photos_qty'].median(), inplace=True)

# Checking
original_rows = final_df_cleaned.shape[0]
dropped_rows = mask_all_missing.sum()  
print(f"Original rows: {original_rows}")
print(f"Rows with all 4 metadata columns missing: {dropped_rows}")
print(f"Remaining rows after drop: {original_rows - dropped_rows}")

print(final_df_cleaned[metadata_cols].isnull().sum())
# Out:
# Original rows: 96282
# Rows with all 4 metadata columns missing: 1401
# Remaining rows after drop: 94881
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# dtype: int64

# %%
cleaned_missing_values_summary = final_df_cleaned.isnull().sum().to_frame(name='Missing Values')
cleaned_missing_values_summary['% Missing'] = (cleaned_missing_values_summary['Missing Values'] / len(final_df_cleaned)) * 100
cleaned_missing_values_summary = cleaned_missing_values_summary[cleaned_missing_values_summary['Missing Values'] > 0]

cleaned_missing_values_summary
# Out:
#                    Missing Values  % Missing
# product_weight_g                1   0.001039
# product_length_cm               1   0.001039
# product_height_cm               1   0.001039
# product_width_cm                1   0.001039

# %%
# Creating a mask where all 4 dimensions are missing
dim_cols = ['product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
mask_all_missing_dims = final_df_cleaned[dim_cols].isnull().all(axis=1)

# Dropping the row
final_df_cleaned = final_df_cleaned[~mask_all_missing_dims]

print(f"Rows dropped due to all product dimensions missing: {mask_all_missing_dims.sum()}")
# Out:
# Rows dropped due to all product dimensions missing: 1

# %%
cleaned_missing_values_summary = final_df_cleaned.isnull().sum().to_frame(name='Missing Values')
cleaned_missing_values_summary['% Missing'] = (cleaned_missing_values_summary['Missing Values'] / len(final_df_cleaned)) * 100
cleaned_missing_values_summary = cleaned_missing_values_summary[cleaned_missing_values_summary['Missing Values'] > 0]

cleaned_missing_values_summary
# Out:
# Empty DataFrame
# Columns: [Missing Values, % Missing]
# Index: []

# %%
# Checking my cleaned dataset

final_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96281 entries, 0 to 98410
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96281 non-null  object
#  1   customer_id                    96281 non-null  object
#  2   order_status                   96281 non-null  object
#  3   order_purchase_timestamp       96281 non-null  datetime64[ns]
#  4   order_approved_at              96281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96281 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96281 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96281 non-null  datetime64[ns]
#  8   customer_unique_id             96281 non-null  object
#  9   customer_zip_code_prefix       96281 non-null  int64
#  10  customer_city                  96281 non-null  object
# ...

# %%
final_df_cleaned.describe()
# Out:
#             order_purchase_timestamp              order_approved_at  \
# count                          96281                          96281
# mean   2018-01-01 23:25:25.933964032  2018-01-02 09:45:29.676550912
# min              2016-09-04 21:15:19            2016-10-04 09:43:32
# 25%              2017-09-13 20:30:02            2017-09-14 04:32:38
# 50%              2018-01-21 12:30:34            2018-01-22 13:59:37
# 75%              2018-05-06 14:28:03            2018-05-07 16:12:24
# max              2018-08-29 15:00:37            2018-08-29 15:10:26
# std                              NaN                            NaN
#
#         order_delivered_carrier_date  order_delivered_customer_date  \
# count                          96281                          96281
# mean   2018-01-05 04:26:59.183462912  2018-01-14 10:28:24.039587584
# min              2016-10-06 09:43:15            2016-10-11 13:46:32
# 25%              2017-09-15 22:33:36            2017-09-25 20:10:15
# ...

# %%
# Saving my cleaned dataset

final_df_cleaned.to_csv('final_df_cleaned.csv', index=False)

# %%
# Saving as Pickle for faster Python reloading

final_df_cleaned.to_pickle("final_df_cleaned.pkl")

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Delivery Delay Analysis: Checking how early or late an order was delivered relative to the estimated date

# %%
# Creating delivery_delay column and assigning values to it
final_df_cleaned['delivery_delay'] = (
    final_df_cleaned['order_delivered_customer_date'] - final_df_cleaned['order_estimated_delivery_date']
).dt.days

final_df_cleaned['delivery_delay']
# Out:
# 0        -8
# 1        -6
# 2       -18
# 3       -13
# 4       -10
#          ..
# 98406   -11
# 98407    -2
# 98408    -6
# 98409   -21
# 98410   -18
# Name: delivery_delay, Length: 96281, dtype: int64

# %%
final_df_cleaned[['order_delivered_customer_date', 'order_estimated_delivery_date', 'delivery_delay']].head(10)
# Out:
#    order_delivered_customer_date order_estimated_delivery_date  delivery_delay
# 0            2017-10-10 21:25:13                    2017-10-18              -8
# 1            2018-08-07 15:27:45                    2018-08-13              -6
# 2            2018-08-17 18:06:29                    2018-09-04             -18
# 3            2017-12-02 00:28:42                    2017-12-15             -13
# 4            2018-02-16 18:17:02                    2018-02-26             -10
# 5            2017-07-26 10:57:55                    2017-08-01              -6
# 7            2017-05-26 12:55:51                    2017-06-07             -12
# 8            2017-02-02 14:08:10                    2017-03-06             -32
# 9            2017-08-16 17:14:30                    2017-08-23              -7
# 10           2017-05-29 11:18:31                    2017-06-07              -9

# %%
final_df_cleaned['delivery_delay'].describe()
# Out:
# count    96281.000000
# mean       -11.999564
# std         10.155542
# min       -147.000000
# 25%        -17.000000
# 50%        -13.000000
# 75%         -7.000000
# max        188.000000
# Name: delivery_delay, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram

plt.figure(figsize=(10, 5))
sns.histplot(final_df_cleaned['delivery_delay'], bins=40, kde=True)
plt.title('Distribution of Delivery Delays (days)')
plt.xlabel('Delivery Delay (days)')
plt.ylabel('Number of Orders')
plt.grid(True)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Checking percentage delay status by categories

def label_delay(days):
    if days > 0:
        return 'Late'
    elif days < 0:
        return 'Early'
    else:
        return 'On Time'

final_df_cleaned['delay_status'] = final_df_cleaned['delivery_delay'].apply(label_delay)

final_df_cleaned['delay_status'].value_counts(normalize=True) * 100
# Out:
# delay_status
# Early      92.089820
# Late        6.585931
# On Time     1.324249
# Name: proportion, dtype: float64

# %%
#Pie Chart

# Counting the number of each delivery status
status_counts = final_df_cleaned['delay_status'].value_counts()

# Creating a pie chart with simple colors
plt.figure(figsize=(6, 6))
plt.pie(
    status_counts, 
    labels=status_counts.index, 
    autopct='%1.1f%%',  # Show percentages on the pie
    startangle=90,      # Rotate to make the first slice start at the top
    colors=['green', 'yellow', 'red']  # Easy-to-remember colors
)
plt.title('Delivery Status Distribution')
plt.axis('equal')  # Keep the pie chart as a circle
plt.show()

# %%
# Bar Chart

# Counting the number of each delivery status
status_counts = final_df_cleaned['delay_status'].value_counts()

# Creating a bar chart
plt.figure(figsize=(8, 5))
plt.bar(status_counts.index, status_counts.values, color=['green', 'red', 'orange'])

# Adding chart title and labels
plt.title('Delivery Status Counts')
plt.xlabel('Delivery Delay Status')
plt.ylabel('Number of Orders')

# Display the chart
plt.show()

# %% [markdown]
# #### Delivery Delay Analysis Summary

# %% [markdown]
# ##### Objective:
# A new column, `delivery_delay`, was created to calculate the difference in days between the actual delivery date and the estimated delivery date for each order.
#
# ##### Key Findings:
# - The average delivery delay is −12 days, meaning most orders arrive earlier than expected.
# - 50% of orders are delivered at least 13 days early.
# - Only 6.6% of orders arrive later than estimated, and just 1.3% arrive exactly on time.
#
# ##### Anomalies and Observations:
# - Some deliveries were up to 147 days early or 188 days late. These may indicate data entry errors or exceptional cases worth reviewing.
# - The very low rate of on-time deliveries suggests that estimated delivery dates may be overly padded or misaligned with actual delivery operations.
#
# ##### Visualizations:
# - A histogram was used to show the full distribution of delivery delays across all orders.
# - A pie chart displays the proportion of Early, Late, and On-Time deliveries.
# - A bar chart shows the number of orders in each delivery category.
#
# ##### Interpretation:
# The company consistently delivers earlier than promised, which is a strong operational advantage. However, reviewing and adjusting estimated delivery windows may improve customer transparency and align expectations more accurately. Outliers should also be reviewed to ensure data quality and prevent reporting issues.

# %% [markdown]
# #### Delivery Time Analysis: Checking how long it took to deliver orders from purchase to custoemr delivery and cross-referencing trends by different factors.

# %%
# Calculating delivery time (in days) as the difference between delivery date and purchase date and creating a new column for the values delivery_time
final_df_cleaned['delivery_time'] = (final_df_cleaned['order_delivered_customer_date'] - final_df_cleaned['order_purchase_timestamp']).dt.days
final_df_cleaned[['order_purchase_timestamp', 'order_delivered_customer_date', 'delivery_time']].head(10)
# Out:
#    order_purchase_timestamp order_delivered_customer_date  delivery_time
# 0       2017-10-02 10:56:33           2017-10-10 21:25:13              8
# 1       2018-07-24 20:41:37           2018-08-07 15:27:45             13
# 2       2018-08-08 08:38:49           2018-08-17 18:06:29              9
# 3       2017-11-18 19:28:06           2017-12-02 00:28:42             13
# 4       2018-02-13 21:18:39           2018-02-16 18:17:02              2
# 5       2017-07-09 21:57:05           2017-07-26 10:57:55             16
# 7       2017-05-16 13:10:30           2017-05-26 12:55:51              9
# 8       2017-01-23 18:29:09           2017-02-02 14:08:10              9
# 9       2017-07-29 11:55:02           2017-08-16 17:14:30             18
# 10      2017-05-16 19:41:10           2017-05-29 11:18:31             12

# %%
final_df_cleaned['delivery_time'].describe()
# Out:
# count    96281.000000
# mean        11.993020
# std          9.382184
# min          0.000000
# 25%          6.000000
# 50%         10.000000
# 75%         15.000000
# max        208.000000
# Name: delivery_time, dtype: float64

# %%
# Categorizing delivery speed based on quartiles from earlier summary
def categorize_speed(days):
    if days <= 5:
        return 'Fast'
    elif days <= 15:
        return 'Moderate'
    else:
        return 'Slow'

# Applying the function to create a new column
final_df_cleaned['delivery_speed'] = final_df_cleaned['delivery_time'].apply(categorize_speed)

final_df_cleaned['delivery_speed'].value_counts(normalize=True) * 100
# Out:
# delivery_speed
# Moderate    56.937506
# Slow        23.489577
# Fast        19.572917
# Name: proportion, dtype: float64

# %%
# Histogram for delivery_time

plt.figure(figsize=(10, 5))
plt.hist(final_df_cleaned['delivery_time'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Delivery Time (Days)')
plt.xlabel('Delivery Time (Days)')
plt.ylabel('Number of Orders')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Boxplot for delivery_time

plt.figure(figsize=(8, 4))
sns.boxplot(x=final_df_cleaned['delivery_time'], color='lightgreen')
plt.title('Boxplot of Delivery Time')
plt.xlabel('Delivery Time (Days)')
plt.tight_layout()
plt.show()

# %%
# Bar chart for delivery_speed

speed_counts = final_df_cleaned['delivery_speed'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(speed_counts.index, speed_counts.values, color=['green', 'orange', 'red'])
plt.title('Order Counts by Delivery Speed')
plt.xlabel('Delivery Speed Category')
plt.ylabel('Number of Orders')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Pie chart for delivery_speed

speed_counts = final_df_cleaned['delivery_speed'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(
    speed_counts, 
    labels=speed_counts.index, 
    autopct='%1.1f%%', 
    startangle=90,
    colors=['orange', 'red', 'green']
)
plt.title('Delivery Speed Distribution')
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Trying to decipher the factors behind orders with fast delivery speeds and slow ones by considering location, product category, seller and season.

# %%
# Counting of delivery speeds by state
state_speed = final_df_cleaned.groupby(['customer_state', 'delivery_speed']).size().unstack().fillna(0)

# Converting to percentages
state_speed_percent = state_speed.div(state_speed.sum(axis=1), axis=0) * 100

# Showing top 20 states by total orders
top_states = final_df_cleaned['customer_state'].value_counts().head(20).index
state_speed_percent.loc[top_states]
# Out:
# delivery_speed       Fast   Moderate       Slow
# customer_state
# SP              36.102868  54.601879   9.295252
# RJ              10.669253  58.058519  31.272228
# MG              12.083038  68.248758  19.668204
# RS               5.359158  60.567883  34.072960
# PR              12.009002  68.637480  19.353519
# SC               6.941679  58.605974  34.452347
# BA               1.498471  45.840979  52.660550
# DF               8.662175  66.410010  24.927815
# ES               2.574457  61.686017  35.739525
# GO               2.521873  62.480700  34.997427
# PE               1.981424  51.455108  46.563467
# CE               1.229823  38.970023  59.800154
# PA               0.535332  29.443255  70.021413
# MT               0.453001  49.830125  49.716874
# MA               1.248266  31.761442  66.990291
# MS               2.578797  59.455587  37.965616
# PB               0.194175  41.359223  58.446602
# PI               1.043841  48.643006  50.313152
# ...

# %%
# Stacked bar chart showing delivery_speed distribution by state

plt.figure(figsize=(14, 7))
state_speed_percent.plot(
    kind='bar',
    stacked=True,
    color=['green', 'orange', 'red'],
    figsize=(16, 7)
)

plt.title('Delivery Speed Distribution by State')
plt.xlabel('Customer State')
plt.ylabel('Percentage of Orders')
plt.legend(title='Delivery Speed')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Identify delivery-related columns in the final merged DataFrame
delay_keywords = ['delay', 'delivery', 'late', 'shipping', 'freight', 'carrier', 'logistic', 'transport', 'date', 'time']

delivery_columns = [col for col in final_df_cleaned.columns if any(keyword in col.lower() for keyword in delay_keywords)]

print("Columns related to delivery, delay, or speed:")
for col in delivery_columns:
    print(f"- {col}")

# Preview those columns
final_df_cleaned[delivery_columns].head()
# Out:
# Columns related to delivery, delay, or speed:
# - order_purchase_timestamp
# - order_delivered_carrier_date
# - order_delivered_customer_date
# - order_estimated_delivery_date
# - shipping_limit_date
# - freight_value
# - review_creation_date
# - review_answer_timestamp
# - delivery_delay
# - delay_status
# - delivery_time
# - delivery_speed
#   order_purchase_timestamp order_delivered_carrier_date  \
# 0      2017-10-02 10:56:33          2017-10-04 19:55:00
# 1      2018-07-24 20:41:37          2018-07-26 14:31:00
# 2      2018-08-08 08:38:49          2018-08-08 13:50:00
# 3      2017-11-18 19:28:06          2017-11-22 13:39:59
# 4      2018-02-13 21:18:39          2018-02-14 19:46:34
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0           2017-10-10 21:25:13                    2017-10-18
# 1           2018-08-07 15:27:45                    2018-08-13
# 2           2018-08-17 18:06:29                    2018-09-04
# ...

# %%
# Grouping by customer_state and calculate average delivery_time
avg_delivery_time_state = final_df_cleaned.groupby('customer_state')['delivery_time'].mean().sort_values(ascending=False)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_delivery_time_state.values, y=avg_delivery_time_state.index, palette='viridis')
plt.title('Average Delivery Time per State', fontsize=14)
plt.xlabel('Average Delivery Time (days)')
plt.ylabel('Customer State')
plt.tight_layout()
plt.show()

# %%
# Grouping by delay_status and calculating average delivery_time
avg_delivery_time = final_df_cleaned.groupby('delay_status')['delivery_time'].mean().sort_values()

# Plotting
plt.figure(figsize=(7, 5))
sns.barplot(x=avg_delivery_time.index, y=avg_delivery_time.values, palette='coolwarm')
plt.title('Average Delivery Time by Delay Status', fontsize=14)
plt.xlabel('Delay Status')
plt.ylabel('Average Delivery Time (days)')
plt.tight_layout()
plt.show()

# %%
# Plotting histogram of delivery_speed
plt.figure(figsize=(8, 5))
sns.histplot(final_df_cleaned['delivery_speed'], bins=30, kde=True, color='mediumseagreen')
plt.title('Distribution of Delivery Speed (days)', fontsize=14)
plt.xlabel('Delivery Speed (days)')
plt.ylabel('Number of Orders')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Boxplot to compare delivery_time across delay_status
plt.figure(figsize=(8, 5))
sns.boxplot(data=final_df_cleaned, x='delay_status', y='delivery_time', palette='Set2')
plt.title('Delivery Time by Delay Status', fontsize=14)
plt.xlabel('Delay Status')
plt.ylabel('Delivery Time (days)')
plt.tight_layout()
plt.show()

# %%
# Extracting month and year
final_df_cleaned['purchase_month'] = final_df_cleaned['order_purchase_timestamp'].dt.to_period('M')

# Grouping by month and calculating average delivery time
monthly_delivery_trend = final_df_cleaned.groupby('purchase_month')['delivery_time'].mean().reset_index()

# Converting Period to datetime for plotting
monthly_delivery_trend['purchase_month'] = monthly_delivery_trend['purchase_month'].dt.to_timestamp()

# Plotting
plt.figure(figsize=(10, 5))
sns.lineplot(data=monthly_delivery_trend, x='purchase_month', y='delivery_time', marker='o', color='teal')
plt.title('Average Delivery Time Over Time', fontsize=14)
plt.xlabel('Month')
plt.ylabel('Average Delivery Time (days)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Grouping by customer state and calculating mean delivery time
state_delivery_time = final_df_cleaned.groupby('customer_state')['delivery_time'].mean().reset_index()

# Sorting by delivery time
state_delivery_time.sort_values(by='delivery_time', ascending=False, inplace=True)

# Plottting
plt.figure(figsize=(14, 7))
sns.barplot(data=state_delivery_time, x='customer_state', y='delivery_time', palette='coolwarm')
plt.title('Average Delivery Time by Customer State')
plt.xlabel('Customer State')
plt.ylabel('Average Delivery Time (days)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Grouping by month for smoother visualization
final_df_cleaned['purchase_month'] = pd.to_datetime(final_df_cleaned['order_purchase_timestamp']).dt.to_period('M')

monthly_delivery = final_df_cleaned.groupby('purchase_month').agg({
    'order_estimated_delivery_date': 'mean',
    'order_delivered_customer_date': 'mean'
}).reset_index()

monthly_delivery['purchase_month'] = monthly_delivery['purchase_month'].astype(str)

# Plottting
plt.figure(figsize=(12, 6))
plt.plot(monthly_delivery['purchase_month'], monthly_delivery['order_estimated_delivery_date'], label='Estimated Delivery', marker='o')
plt.plot(monthly_delivery['purchase_month'], monthly_delivery['order_delivered_customer_date'], label='Actual Delivery', marker='x')

plt.xticks(rotation=45)
plt.title('Estimated vs Actual Delivery Dates Over Time')
plt.xlabel('Purchase Month')
plt.ylabel('Average Delivery Date')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Checking summary stats and unique values
print(final_df_cleaned['delivery_speed'].describe())
print("\nUnique delivery_speed values:")
print(final_df_cleaned['delivery_speed'].unique())
# Out:
# count        96281
# unique           3
# top       Moderate
# freq         54820
# Name: delivery_speed, dtype: object
#
# Unique delivery_speed values:
# ['Moderate' 'Fast' 'Slow']

# %%
# Checking for missing timestamps that could have caused NaNs
final_df_cleaned[['order_purchase_timestamp', 'order_delivered_customer_date']].isnull().sum()
# Out:
# order_purchase_timestamp         0
# order_delivered_customer_date    0
# dtype: int64

# %%
# Recalculating delivery_speed in days
final_df_cleaned['delivery_speed'] = (
    final_df_cleaned['order_delivered_customer_date'] - final_df_cleaned['order_purchase_timestamp']
).dt.days

# Check if values were calculated correctly
print(final_df_cleaned['delivery_speed'].describe())
print(final_df_cleaned['delivery_speed'].unique()[:10])  # Showing a sample
# Out:
# count    96281.000000
# mean        11.993020
# std          9.382184
# min          0.000000
# 25%          6.000000
# 50%         10.000000
# 75%         15.000000
# max        208.000000
# Name: delivery_speed, dtype: float64
# [ 8 13  9  2 16 18 12  5  4 11]

# %%
# Filtering to keep only product categories with at least 100 orders
category_counts = final_df_cleaned['product_category_name'].value_counts()
valid_categories = category_counts[category_counts >= 100].index

filtered_df = final_df_cleaned[final_df_cleaned['product_category_name'].isin(valid_categories)]

# Plotting delivery speed by product category
plt.figure(figsize=(14, 6))
sns.boxplot(
    x='product_category_name',
    y='delivery_speed',
    data=filtered_df
)
plt.xticks(rotation=90)
plt.title('Delivery Speed by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Delivery Speed (days)')
plt.tight_layout()
plt.show()

# %%
final_df_cleaned.columns.tolist()
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state',
#  'order_item_id',
#  'product_id',
#  'seller_id',
#  'shipping_limit_date',
#  'price',
#  'freight_value',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value',
#  'review_id',
#  'review_score',
#  'review_comment_title',
#  'review_comment_message',
#  'review_creation_date',
#  'review_answer_timestamp',
#  'product_category_name',
#  'product_name_lenght',
#  'product_description_lenght',
#  'product_photos_qty',
#  'product_weight_g',
#  'product_length_cm',
#  'product_height_cm',
#  'product_width_cm',
#  'delivery_delay',
#  'delay_status',
#  'delivery_time',
#  'delivery_speed',
#  'purchase_month']

# %%
import os

# Setting output folder
output_dir = "marketmetrics_charts"
os.makedirs(output_dir, exist_ok=True)

# Function to auto-save all open figures
def save_all_figures(folder=output_dir, format="png"):
    for i in plt.get_fignums():
        fig = plt.figure(i)
        fig_path = os.path.join(folder, f"figure_{i}.{format}")
        fig.savefig(fig_path, dpi=300, bbox_inches='tight')
        print(f"Saved: {fig_path}")

# Callling the function after all your plots are generated
save_all_figures()

# %%
final_df_cleaned.to_csv("marketmetrics_cleaned_for_powerbi.csv", index=False)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\MarketMetrics'
